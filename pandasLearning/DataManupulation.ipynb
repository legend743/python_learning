# %%
import pandas as pd
import numpy as np

# %%
iris=pd.read_csv('./iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df=iris
df.drop(0)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]

# %%
df.index[7]
# Out:
# 7

# %%
df.drop(4)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]

# %%
df.drop(0,inplace=True) # while you give inplace=True mean you permanently delete the data from the csv file

# %%
# when permanently deleted a row again you want to delete that row will give error

df.drop(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\legen\Pyhton_Jupyter\python_learning\pandasLearning\DataManupulation.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/legen/Pyhton_Jupyter/python_learning/pandasLearning/DataManupulation.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df.drop(0)
#
# File c:\Users\legen\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]>

# %%
#iloc me i indexing k according bata rha h and loc means location
df.iloc[0]
# Out:
# sepal.length       4.9
# sepal.width        3.0
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 1, dtype: object

# %%
df.loc[6]
#in loc means location whcih  give you according to the location of label
# Out:
# sepal.length       4.6
# sepal.width        3.4
# petal.length       1.4
# petal.width        0.3
# variety         Setosa
# Name: 6, dtype: object

# %%
#to add a new row
df.loc[0]=[5.6,7.6,8,90,'setosa']

# %%
df.head
# Out:
# <bound method NDFrame.head of      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 0             5.6          7.6           8.0         90.0     setosa
#
# [150 rows x 5 columns]>

# %%
df.tail
#row has been added in tale
# Out:
# <bound method NDFrame.tail of      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 0             5.6          7.6           8.0         90.0     setosa
#
# [150 rows x 5 columns]>

# %%
#to resest index
#but by doing this a column has been added neamed index

df.reset_index()
# Out:
#      index  sepal.length  sepal.width  petal.length  petal.width    variety
# 0        1           4.9          3.0           1.4          0.2     Setosa
# 1        2           4.7          3.2           1.3          0.2     Setosa
# 2        3           4.6          3.1           1.5          0.2     Setosa
# 3        4           5.0          3.6           1.4          0.2     Setosa
# 4        5           5.4          3.9           1.7          0.4     Setosa
# ..     ...           ...          ...           ...          ...        ...
# 145    146           6.3          2.5           5.0          1.9  Virginica
# 146    147           6.5          3.0           5.2          2.0  Virginica
# 147    148           6.2          3.4           5.4          2.3  Virginica
# 148    149           5.9          3.0           5.1          1.8  Virginica
# 149      0           5.6          7.6           8.0         90.0     setosa
#
# [150 rows x 6 columns]

# %%
#to remove and want that new index column will ot come so we use
df.reset_index(drop=True)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             4.9          3.0           1.4          0.2     Setosa
# 1             4.7          3.2           1.3          0.2     Setosa
# 2             4.6          3.1           1.5          0.2     Setosa
# 3             5.0          3.6           1.4          0.2     Setosa
# 4             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.3          2.5           5.0          1.9  Virginica
# 146           6.5          3.0           5.2          2.0  Virginica
# 147           6.2          3.4           5.4          2.3  Virginica
# 148           5.9          3.0           5.1          1.8  Virginica
# 149           5.6          7.6           8.0         90.0     setosa
#
# [150 rows x 5 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 0             5.6          7.6           8.0         90.0     setosa
#
# [150 rows x 5 columns]>

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
df.drop('sepal.length')
#it will give you error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\legen\Pyhton_Jupyter\python_learning\pandasLearning\DataManupulation.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/legen/Pyhton_Jupyter/python_learning/pandasLearning/DataManupulation.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> df.drop('sepal.length')
#
# File c:\Users\legen\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
# ...

# %%
df.drop('sepal.length',axis=1) # this is temporary deletion,axis=1 ka matlab columns me dekho,or inplace aagar daal doge to matlab copy me nai actual data frame me delete krdo
# Out:
#      sepal.width  petal.length  petal.width    variety
# 1            3.0           1.4          0.2     Setosa
# 2            3.2           1.3          0.2     Setosa
# 3            3.1           1.5          0.2     Setosa
# 4            3.6           1.4          0.2     Setosa
# 5            3.9           1.7          0.4     Setosa
# ..           ...           ...          ...        ...
# 146          2.5           5.0          1.9  Virginica
# 147          3.0           5.2          2.0  Virginica
# 148          3.4           5.4          2.3  Virginica
# 149          3.0           5.1          1.8  Virginica
# 0            7.6           8.0         90.0     setosa
#
# [150 rows x 4 columns]

# %%
df.head(
)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
df.columns=['sl','sw','pl','pw','kind']

# %%
df.head()
#Now column has been changed according to given colun name
# Out:
#     sl   sw   pl   pw    kind
# 1  4.9  3.0  1.4  0.2  Setosa
# 2  4.7  3.2  1.3  0.2  Setosa
# 3  4.6  3.1  1.5  0.2  Setosa
# 4  5.0  3.6  1.4  0.2  Setosa
# 5  5.4  3.9  1.7  0.4  Setosa

# %%
df.head()
# Out:
#     sl   sw   pl   pw    kind
# 1  4.9  3.0  1.4  0.2  Setosa
# 2  4.7  3.2  1.3  0.2  Setosa
# 3  4.6  3.1  1.5  0.2  Setosa
# 4  5.0  3.6  1.4  0.2  Setosa
# 5  5.4  3.9  1.7  0.4  Setosa

# %%
df.iloc[1:2,0:3]=np.NaN

# %%
df.head()
# Out:
#     sl   sw   pl   pw    kind
# 1  4.9  3.0  1.4  0.2  Setosa
# 2  NaN  NaN  NaN  0.2  Setosa
# 3  4.6  3.1  1.5  0.2  Setosa
# 4  5.0  3.6  1.4  0.2  Setosa
# 5  5.4  3.9  1.7  0.4  Setosa

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  150.000000
# mean     5.854362    3.083893    3.818792    1.798000
# std      0.823431    0.573169    1.782360    7.289493
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    7.600000    8.000000   90.000000

# %%
#you can directly frop that rows
# yo can also fill that rows by mean method
df.sw.mean()
# Out:
# 3.0838926174496644

# %%
df.sw()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\legen\Pyhton_Jupyter\python_learning\pandasLearning\DataManupulation.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/legen/Pyhton_Jupyter/python_learning/pandasLearning/DataManupulation.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> df.sw()
#
# TypeError: 'Series' object is not callable

# %%
df.sw
# Out:
# 1      3.0
# 2      NaN
# 3      3.1
# 4      3.6
# 5      3.9
#       ...
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# 0      7.6
# Name: sw, Length: 150, dtype: float64

# %%
df.sw.fillna(df.sw.mean(),inplace=True)

# %%
df.sw
# Out:
# 1      3.000000
# 2      3.083893
# 3      3.100000
# 4      3.600000
# 5      3.900000
#          ...
# 146    2.500000
# 147    3.000000
# 148    3.400000
# 149    3.000000
# 0      7.600000
# Name: sw, Length: 150, dtype: float64

# %%
df.head
# Out:
# <bound method NDFrame.head of       sl        sw   pl    pw       kind
# 1    4.9  3.000000  1.4   0.2     Setosa
# 2    NaN  3.083893  NaN   0.2     Setosa
# 3    4.6  3.100000  1.5   0.2     Setosa
# 4    5.0  3.600000  1.4   0.2     Setosa
# 5    5.4  3.900000  1.7   0.4     Setosa
# ..   ...       ...  ...   ...        ...
# 146  6.3  2.500000  5.0   1.9  Virginica
# 147  6.5  3.000000  5.2   2.0  Virginica
# 148  6.2  3.400000  5.4   2.3  Virginica
# 149  5.9  3.000000  5.1   1.8  Virginica
# 0    5.6  7.600000  8.0  90.0     setosa
#
# [150 rows x 5 columns]>

# %%
df.fillna(df.pw.value(0),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9380\3921061975.py in ?()
# ----> 1 df.fillna(df.pw.value(0),inplace=True)
#
# c:\Users\legen\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value'
